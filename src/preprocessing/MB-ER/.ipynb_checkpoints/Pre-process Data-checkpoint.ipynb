# %%
import sys
sys.path.append('C:/Users/sumaiyah/OneDrive - University Of Cambridge/Project/NN-Builder/src/preprocessing/')

# %%
# Python Libraries
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %% [markdown]
# # Generate Training and test data from the Metabric dataset
# For ER +/- classification

# %%
data = pd.read_csv('data.csv')
# Out:
# c:\users\sumaiyah\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# only considering a subset of genes shows to have biological relevance
feature_col_names = [col for col in data if col.startswith('GE_')]

target_col_name = 'ER_Expr'
data = data[feature_col_names+[target_col_name]].rename(columns={target_col_name: 'target'})

data.head()
# Out:
#     GE_GRB7    GE_LSM1  GE_CLNS1A  GE_STARD3  GE_PPFIA1   GE_ERBB2  GE_INTS4  \
# 0  6.487146  11.031136  10.079148   6.031175   9.487621   9.729606  8.253549
# 1  6.479166  10.873850  10.322188   5.846570   9.053110   9.725825  7.873861
# 2  7.874277  11.381911   9.550389   6.212065   8.822194  10.334979  7.312676
# 3  6.351296  10.433402   9.736490   5.885852   8.981401   9.739996  7.728910
# 4  6.354046  11.074266   9.968607   5.876592   8.861144   9.276507  7.643929
#
#    GE_ORMDL3   GE_PSMB3  GE_MTERFD1  ...  GE_ZNHIT3  GE_FOXM1  GE_EXOC3  \
# 0   6.511952  10.423016    8.419615  ...   7.922863  5.677913  7.426484
# 1   6.627166  11.203083    8.515613  ...   8.724618  6.054136  7.013241
# 2   7.164516  11.910947    9.153356  ...   9.420298  5.774602  7.374062
# 3   6.663150  11.050693    8.540313  ...   7.378990  6.735173  7.453835
# 4   6.793206  11.425601    8.650009  ...   9.538950  5.665971  6.726317
#
#    GE_ARMC7  GE_KCTD2  GE_PDCD10   GE_RHOD   GE_YBX1  GE_TRIM24  target
# 0  6.194931  5.962671   9.093493  9.407661  9.526590   7.306828       +
# 1  6.641685  5.784853   9.330020  8.623256  9.545137   8.624840       +
# 2  6.782999  6.655940   9.856422  9.663621  9.942894   8.278145       +
# 3  7.132947  6.392015   8.899136  8.579820  9.795769   7.705012       +
# 4  6.362663  6.229215  10.877762  8.127024  9.346105   7.549302       +
#
# [5 rows x 1001 columns]

# %%
# Column names
col_names = data.columns

# %%
data['target'].replace({'+':1, '-':0}, inplace=True)  # encode '+' as 1 and '-'' as 0

# %%
X = data.iloc[:,0:1000].values  # [rows, cols]
y = data['target'].values

# %%
# Scale attributes so that theyre 0-1 so that larger weights do not carry more signifcance in the network
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler() 
X = scaler.fit_transform(X)

# %%
# Split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# Save data 
from helpers import save_data
save_data(X=X_train, y=y_train, col_names=col_names, filename='train_data.csv')
save_data(X=X_test, y=y_test, col_names=col_names, filename='test_data.csv')

# %%
# NN Structure: 1000-100-50-2
# Batchsize: 15, Epochs: 100
# Activation Function: tanh

# %%
import pandas as pd
pd.read_csv('trainn_data.csv')
# Out:
#       GE_GRB7   GE_LSM1  GE_CLNS1A  GE_STARD3  GE_PPFIA1  GE_ERBB2  GE_INTS4  \
# 0    0.668274  0.337398   0.307439   0.261563   0.227144  0.947739  0.213853
# 1    0.219488  0.492952   0.370000   0.151955   0.209349  0.384412  0.210161
# 2    0.658623  0.188822   0.237502   0.530186   0.139481  0.905597  0.133929
# 3    0.350867  0.629659   0.354478   0.236762   0.260964  0.604617  0.209075
# 4    0.206804  0.384364   0.353918   0.137465   0.176282  0.414169  0.166759
# ..        ...       ...        ...        ...        ...       ...       ...
# 391  0.231030  0.427474   0.188986   0.190576   0.700462  0.363618  0.070981
# 392  0.442296  0.314062   0.339710   0.184111   0.235928  0.595111  0.194277
# 393  0.183365  0.361084   0.337919   0.107651   0.203575  0.440456  0.175471
# 394  0.248369  0.270779   0.145284   0.126967   0.115241  0.540264  0.134026
# 395  0.799773  0.178614   0.307071   0.715025   0.043452  0.944769  0.200373
#
#      GE_ORMDL3  GE_PSMB3  GE_MTERFD1  ...  GE_ZNHIT3  GE_FOXM1  GE_EXOC3  \
# 0     0.422909  0.526839    0.548700  ...   0.257409  0.558776  0.539208
# 1     0.132073  0.227991    0.781655  ...   0.271270  0.262286  0.415836
# 2     0.210894  0.272014    0.500727  ...   0.465461  0.425365  0.547311
# 3     0.405307  0.508713    0.616397  ...   0.382292  0.346092  0.370519
# 4     0.233700  0.245013    0.414054  ...   0.433432  0.147648  0.463209
# ..         ...       ...         ...  ...        ...       ...       ...
# 391   0.242776  0.240615    0.498658  ...   0.272587  0.399517  0.331773
# 392   0.192254  0.118499    0.459331  ...   0.445620  0.139105  0.493685
# 393   0.225568  0.262592    0.312615  ...   0.489459  0.219287  0.456618
# 394   0.155708  0.269891    0.289044  ...   0.435927  0.251998  0.399759
# 395   0.835830  0.845076    0.581724  ...   0.382651  0.238406  0.454726
#
#      GE_ARMC7  GE_KCTD2  GE_PDCD10   GE_RHOD   GE_YBX1  GE_TRIM24  target
# 0    0.489576  0.380046   0.554614  0.582401  0.480138   0.381346       0
# 1    0.270411  0.198813   0.497297  0.661961  0.495992   0.345220       1
# 2    0.335402  0.287492   0.537365  0.531494  0.609698   0.367061       1
# 3    0.640743  0.333311   0.711527  0.632967  0.276915   0.347388       1
# 4    0.240818  0.161563   0.481993  0.417120  0.512070   0.338242       1
# ..        ...       ...        ...       ...       ...        ...     ...
# 391  0.448125  0.292688   0.522598  0.444679  0.357560   0.259767       1
# 392  0.348224  0.251802   0.499833  0.441426  0.481823   0.335646       0
# 393  0.491408  0.446648   0.541274  0.504506  0.309467   0.629475       1
# 394  0.262020  0.332922   0.413968  0.389672  0.483250   0.286725       1
# 395  0.223201  0.165258   0.555504  0.576058  0.682896   0.543670       0
#
# [396 rows x 1001 columns]
